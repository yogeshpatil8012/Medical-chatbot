# %%
# %pwd
# Out:
# 'c:\\Users\\HP\\Langchain\\Projects\\Medical Chatbot\\Medical-chatbot\\research'

# %%
import os
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\HP\\Langchain\\Projects\\Medical Chatbot\\Medical-chatbot'

# %%
from langchain.document_loaders import PyPDFLoader
